# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Opening the data

# %%
df = pd.read_csv(r'C:\Users\Sarik\Downloads\Projects For DA\Capston Projects\Sales store\sales_store_updated_allign_with_video.csv')
df
# Out:
#      transaction_id customer_id   customer_name  customer_age  gender  \
# 0         TXN886726    CUST4481  Dhanush Bhakta          41.0       F
# 1         TXN941069    CUST9221  Anahita Shenoy          46.0       F
# 2         TXN132714    CUST9088    Samaira Bora          29.0  Female
# 3         TXN855235    CUST5938   Yashvi Sachar          44.0    Male
# 4         TXN570157    CUST1985      Rhea Manda          45.0  Female
# ...             ...         ...             ...           ...     ...
# 2000      TXN194804    CUST1534  Manjari Sachar          51.0  Female
# 2001      TXN801958    CUST7264    Jayesh Bandi          30.0       M
# 2002      TXN416394    CUST3887    Amani Shukla          25.0       M
# 2003      TXN541709    CUST8436       Siya Mane          39.0    Male
# 2004      TXN814419    CUST9709     Suhana Sule          26.0       M
#
#      product_id product_name product_category  quantiy   prce payment_mode  \
# ...

# %% [markdown]
# # Checking the total rows and columns

# %%
df.shape
# Out:
# (2005, 14)

# %% [markdown]
# # Checking the  columns name

# %%
df.columns
# Out:
# Index(['transaction_id', 'customer_id', 'customer_name', 'customer_age',
#        'gender', 'product_id', 'product_name', 'product_category', 'quantiy',
#        'prce', 'payment_mode', 'purchase_date', 'time_of_purchase', 'status'],
#       dtype='object')

# %% [markdown]
# # Checking the null values

# %%
df.isnull().sum()
# Out:
# transaction_id      1
# customer_id         3
# customer_name       2
# customer_age        2
# gender              2
# product_id          0
# product_name        0
# product_category    0
# quantiy             0
# prce                0
# payment_mode        1
# purchase_date       1
# time_of_purchase    1
# status              1
# dtype: int64

# %% [markdown]
# # Checking the null value percentage

# %%
df.isnull().sum()/len(df)
# Out:
# transaction_id      0.000499
# customer_id         0.001496
# customer_name       0.000998
# customer_age        0.000998
# gender              0.000998
# product_id          0.000000
# product_name        0.000000
# product_category    0.000000
# quantiy             0.000000
# prce                0.000000
# payment_mode        0.000499
# purchase_date       0.000499
# time_of_purchase    0.000499
# status              0.000499
# dtype: float64

# %% [markdown]
# # Deleting the null value

# %%
df.dropna(inplace = True)

# %% [markdown]
# # Checking if null is deleted

# %%
df.shape
# Out:
# (2001, 14)

# %%
df.isnull().sum()
# Out:
# transaction_id      0
# customer_id         0
# customer_name       0
# customer_age        0
# gender              0
# product_id          0
# product_name        0
# product_category    0
# quantiy             0
# prce                0
# payment_mode        0
# purchase_date       0
# time_of_purchase    0
# status              0
# dtype: int64

# %% [markdown]
# # Changing the datatypes

# %%
df['purchase_date'] = pd.to_datetime(df['purchase_date'])
# Out:
# C:\Users\Sarik\AppData\Local\Temp\ipykernel_18052\1550872345.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['purchase_date'] = pd.to_datetime(df['purchase_date'])

# %%
df['purchase_date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df['customer_age'] = df['customer_age'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2001 entries, 0 to 2004
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_id    2001 non-null   object
#  1   customer_id       2001 non-null   object
#  2   customer_name     2001 non-null   object
#  3   customer_age      2001 non-null   int64
#  4   gender            2001 non-null   object
#  5   product_id        2001 non-null   object
#  6   product_name      2001 non-null   object
#  7   product_category  2001 non-null   object
#  8   quantiy           2001 non-null   int64
#  9   prce              2001 non-null   int64
#  10  payment_mode      2001 non-null   object
#  11  purchase_date     2001 non-null   datetime64[ns]
#  12  time_of_purchase  2001 non-null   object
#  13  status            2001 non-null   object
# dtypes: datetime64[ns](1), int64(3), object(10)
# memory usage: 234.5+ KB

# %%
df['time_of_purchase'] = pd.to_datetime(df['time_of_purchase'],format = '%H:%M:%S')

# %% [markdown]
# # Correcting the column name

# %%
df.rename(columns = {'quantiy' : 'quantity' , 'prce' : 'price'}, inplace  = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2001 entries, 0 to 2004
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_id    2001 non-null   object
#  1   customer_id       2001 non-null   object
#  2   customer_name     2001 non-null   object
#  3   customer_age      2001 non-null   int64
#  4   gender            2001 non-null   object
#  5   product_id        2001 non-null   object
#  6   product_name      2001 non-null   object
#  7   product_category  2001 non-null   object
#  8   quantity          2001 non-null   int64
#  9   price             2001 non-null   int64
#  10  payment_mode      2001 non-null   object
#  11  purchase_date     2001 non-null   datetime64[ns]
#  12  time_of_purchase  2001 non-null   object
#  13  status            2001 non-null   object
# dtypes: datetime64[ns](1), int64(3), object(10)
# memory usage: 234.5+ KB

# %% [markdown]
# #  Correcting the values

# %%
df['gender'].nunique()
# Out:
# 4

# %%
df['gender'].unique()
# Out:
# array(['F', 'Female', 'Male', 'M'], dtype=object)

# %%
df['gender'] = df['gender'].replace({'F':'Female', 'M':'Male'})

# %%
df.head()
# Out:
#   transaction_id customer_id   customer_name  customer_age  gender product_id  \
# 0      TXN886726    CUST4481  Dhanush Bhakta            41  Female      P8464
# 1      TXN941069    CUST9221  Anahita Shenoy            46  Female      P7932
# 2      TXN132714    CUST9088    Samaira Bora            29  Female      P9223
# 3      TXN855235    CUST5938   Yashvi Sachar            44    Male      P6308
# 4      TXN570157    CUST1985      Rhea Manda            45  Female      P5718
#
#   product_name product_category  quantity  price payment_mode purchase_date  \
# 0         Sofa        Furniture         5  21410          UPI    2023-08-29
# 1   Sunglasses      Accessories         2   1156         Cash    2023-06-04
# 2   Sunglasses      Accessories         4  13828          UPI    2023-09-16
# 3   Smartwatch      Electronics         3  11214          EMI    2023-08-26
# 4     Wardrobe        Furniture         4   6120          EMI    2023-11-23
#
#   time_of_purchase     status
# ...

# %%
df['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['product_name'].unique()
# Out:
# array(['Sofa', 'Sunglasses', 'Smartwatch', 'Wardrobe', 'Sweater',
#        'Vegetables', 'Dining Table', 'Fruits', 'Laptop', 'Shirt', 'Wheat',
#        'Tablet', 'Handbag', 'Jacket', 'Magazine', 'Jeans', 'Chair',
#        'T-Shirt', 'Novel', 'Milk', 'Headphones', 'Notebook', 'Belt',
#        'Smartphone', 'Bed', 'Textbook', 'Comics', 'Wallet', 'Rice',
#        'Watch'], dtype=object)

# %%
df['product_category'].unique()
# Out:
# array(['Furniture', 'Accessories', 'Electronics', 'Clothing', 'Groceries',
#        'Books'], dtype=object)

# %%
df['payment_mode'].unique()
# Out:
# array(['UPI', 'Cash', 'EMI', 'Debit Card', 'CC', 'Credit Card'],
#       dtype=object)

# %%
df['payment_mode'] = df['payment_mode'].replace({'CC' : 'Credit Card'})

# %%
df['payment_mode'].unique()
# Out:
# array(['UPI', 'Cash', 'EMI', 'Debit Card', 'Credit Card'], dtype=object)

# %%
df['status'].unique()
# Out:
# array(['pending', 'cancelled', 'delivered', 'returned'], dtype=object)

# %% [markdown]
# # Checking duplicates

# %%
df[df.duplicated()]
# Out:
#     transaction_id customer_id       customer_name  customer_age  gender  \
# 11       TXN855235    CUST5938       Yashvi Sachar            44    Male
# 50       TXN342128    CUST1214        Nehmat Batta            39    Male
# 100      TXN240646    CUST5356          Renee Kant            37  Female
# 233      TXN981773    CUST2365  Tushar Chakrabarti            50    Male
#
#     product_id product_name product_category  quantity  price payment_mode  \
# 11       P6308   Smartwatch      Electronics         3  11214          EMI
# 50       P1286      Sweater         Clothing         3   1284         Cash
# 100      P4193     Textbook            Books         2   9770          UPI
# 233      P5760         Milk        Groceries         4   4120         Cash
#
#     purchase_date time_of_purchase     status
# 11     2023-08-26         16:59:09  delivered
# 50     2023-08-24         20:05:11   returned
# 100    2023-09-23         11:43:16  cancelled
# ...

# %%
df.drop_duplicates(inplace = True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [transaction_id, customer_id, customer_name, customer_age, gender, product_id, product_name, product_category, quantity, price, payment_mode, purchase_date, time_of_purchase, status]
# Index: []

# %% [markdown]
# # Checking outliers

# %%
columns = ['customer_age' , 'quantity', 'price']

# %%
plt.figure(figsize=(8,4))
sns.boxplot(data=df[columns])
plt.title("Boxplots of Selected Columns")
plt.show()

# %%
columns = ['customer_age' , 'quantity', 'price']

for col in columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)

    IQR = Q3-Q1

    LB = Q1-1.5*IQR
    UB = Q3+1.5*IQR

    md = df[col].median()

    outlier = (df[col] < LB) | (df[col] > UB)
    
outlier.sum()
# Out:
# np.int64(3)

# %%
columns = ['customer_age' , 'quantity', 'price']

for col in columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)

    IQR = Q3-Q1

    LB = Q1-1.5*IQR
    UB = Q3+1.5*IQR

    df[col] = np.where(df[col] < LB, LB, np.where(df[col] > UB, UB, df[col]))

# %%
plt.figure(figsize=(8,4))
sns.boxplot(data=df[columns])
plt.title("Boxplots of Selected Columns")
plt.show()

# %% [markdown]
# #  EDA

# %%
df.describe()
# Out:
#        customer_age     quantity         price                  purchase_date
# count   1997.000000  1997.000000   1997.000000                           1997
# mean      38.896845     3.042564   7952.299199  2023-07-04 23:21:03.695543552
# min       18.000000     1.000000    101.000000            2023-01-01 00:00:00
# 25%       28.000000     2.000000   2948.000000            2023-04-04 00:00:00
# 50%       39.000000     3.000000   6634.000000            2023-07-09 00:00:00
# 75%       50.000000     4.000000  11745.000000            2023-10-05 00:00:00
# max       60.000000     5.000000  24940.500000            2024-01-01 00:00:00
# std       12.638348     1.413395   6048.221217                            NaN

# %%
df['Total_Sales'] = df['quantity']*df['price']

# %% [markdown]
# # Analysis on Gender basis

# %%
ax= sns.countplot(data = df, x = 'gender', palette = 'Set2')
plt.title('Customer Count by Gender"')
for bar in ax.containers:
    ax.bar_label(bar)
# Out:
# C:\Users\Sarik\AppData\Local\Temp\ipykernel_18052\4149734419.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax= sns.countplot(data = df, x = 'gender', palette = 'Set2')

# %%
df.groupby('gender')['Total_Sales'].sum()
# Out:
# gender
# Female    29576404.0
# Male      29440135.5
# Name: Total_Sales, dtype: float64

# %%
t = df.groupby('gender')['Total_Sales'].sum().plot(kind = 'bar', color = 'orange')
plt.title('Total Spend By Gender')

for bar in t.containers:
    t.bar_label(bar)

# %%
y = df.groupby('gender')['quantity'].sum().plot(kind = 'bar', color = 'blue')

plt.title('Total Purchase Qty By Gender')

for bar in y.containers:
    y.bar_label(bar)

# %% [markdown]
# Customer Count: Majority are Male.
# Spending: Female customers spend more money than Male customers.
# Quantity: Female customers also purchase slightly more items.

# %% [markdown]
# #  Top 10 Customers on the basis on total sales and qty

# %%
df.groupby('customer_name')['quantity'].sum().sort_values(ascending = False).head(10)
# Out:
# customer_name
# Manikya Walia        39.0
# Saira Ahluwalia      35.0
# Darshit Mann         35.0
# Gatik Khare          34.0
# Jiya Comar           31.0
# Onkar Devan          30.0
# Renee Biswas         30.0
# Badal Ratti          29.0
# Mannat Contractor    29.0
# Seher Solanki        29.0
# Name: quantity, dtype: float64

# %%
plt.figure(figsize = (14,4))
a = df.groupby('customer_name')['quantity'].sum().sort_values(ascending = False).head(10).plot(kind = 'bar', color = 'pink')
plt.title("Top 10 Customers by Quantity")
for bar in a.containers:
    a.bar_label(bar)

# %%
df.groupby('customer_name')['Total_Sales'].sum().sort_values(ascending = False).head(10)
# Out:
# customer_name
# Darshit Mann           507530.0
# Anahita Shenoy         455637.0
# Saira Ahluwalia        447933.0
# Gatik Khare            386108.5
# Samaira Subramaniam    357388.0
# Rohan Kalla            353098.0
# Taimur Viswanathan     346568.0
# Manikya Walia          344736.0
# Badal Ratti            342470.0
# Seher Randhawa         330344.0
# Name: Total_Sales, dtype: float64

# %%
plt.figure(figsize = (14,4))
a = df.groupby('customer_name')['Total_Sales'].sum().sort_values(ascending = False).head(10).plot(kind = 'bar', color = 'yellow')
plt.title("Top 10 Customers by Total_Sales")
for bar in a.containers:
    a.bar_label(bar)

# %% [markdown]
# #  Age wise analysis

# %%
df['customer_age'].value_counts().sort_values(ascending = False)
# Out:
# customer_age
# 57.0    85
# 41.0    75
# 31.0    74
# 23.0    67
# 51.0    65
# 24.0    64
# 39.0    63
# 30.0    60
# 58.0    58
# 56.0    56
# 47.0    56
# 18.0    55
# 35.0    54
# 34.0    54
# 20.0    54
# 29.0    54
# 44.0    52
# 25.0    51
# 46.0    48
# 50.0    48
# 60.0    47
# 19.0    44
# 37.0    44
# 52.0    43
# 28.0    41
# 22.0    41
# 38.0    40
# 36.0    39
# 45.0    37
# 54.0    36
# 49.0    35
# 59.0    35
# 33.0    34
# 53.0    33
# 43.0    33
# 55.0    32
# 32.0    31
# 40.0    30
# 21.0    30
# 27.0    30
# 26.0    29
# 48.0    25
# 42.0    15
# Name: count, dtype: int64

# %%
plt.figure(figsize = (15,4))
b = df['customer_age'].value_counts().sort_values(ascending = False).plot(kind = 'bar')
plt.title("Customer Count by Age")
for bar in b.containers:
    b.bar_label(bar)

# %%
df.groupby('customer_age')['Total_Sales'].sum().sort_values(ascending = False)
# Out:
# customer_age
# 57.0    2674439.0
# 41.0    2394071.0
# 39.0    2249062.0
# 31.0    1991570.0
# 24.0    1922628.0
# 51.0    1895832.0
# 23.0    1809521.0
# 60.0    1756374.0
# 18.0    1739388.0
# 58.0    1651047.0
# 30.0    1648960.0
# 44.0    1644530.0
# 46.0    1606502.0
# 20.0    1583359.0
# 28.0    1570031.5
# 35.0    1541790.0
# 47.0    1524098.0
# 56.0    1510840.0
# 29.0    1486744.0
# 50.0    1387541.0
# 38.0    1375099.0
# 22.0    1342584.0
# 25.0    1302410.0
# 34.0    1301566.0
# 33.0    1276833.0
# 37.0    1206050.0
# 52.0    1146827.0
# 45.0    1084799.5
# 27.0    1041551.0
# 40.0    1037589.0
# 54.0    1032933.0
# 26.0     997935.0
# 19.0     992506.0
# 36.0     982799.0
# 53.0     959848.5
# 43.0     954678.0
# 59.0     924059.0
# 49.0     901545.0
# 55.0     834241.0
# 32.0     831961.0
# 21.0     829358.0
# 48.0     661884.0
# 42.0     409156.0
# Name: Total_Sales, dtype: float64

# %%
plt.figure(figsize = (15,4))
df.groupby('customer_age')['Total_Sales'].sum().sort_values(ascending = False).plot(kind = 'bar', color = 'green')
plt.title("Total Spent by Age")
# Out:
# Text(0.5, 1.0, 'Total Spent by Age')

# %%
plt.figure(figsize = (15,4))
df.groupby('customer_age')['quantity'].sum().sort_values(ascending = False).plot(kind = 'bar')
plt.title("Total Purchased Qty by Age")
# Out:
# Text(0.5, 1.0, 'Total Purchased Qty by Age')

# %% [markdown]
# Ages 57, 41, 31, 39, 51 are key contributors to revenue.
# This suggests that middle-aged customers (30–60) are your most valuable demographic.
# Marketing and promotions could be focused on these age groups.

# %% [markdown]
# # Top 10 product

# %%
df.groupby('product_name')['quantity'].sum().sort_values(ascending = False).head(10)
# Out:
# product_name
# Vegetables    253.0
# Notebook      230.0
# Chair         228.0
# Jacket        227.0
# Wardrobe      227.0
# Sweater       226.0
# T-Shirt       224.0
# Belt          222.0
# Shirt         220.0
# Smartphone    217.0
# Name: quantity, dtype: float64

# %%
plt.figure(figsize = (10,4))
s = df.groupby('product_name')['quantity'].sum().sort_values(ascending = False).head(10).plot(kind = 'bar')
plt.title("Top 10 Products by Qty")
for bar in s.containers:
    s.bar_label(bar)

# %%
df.groupby('product_name')['Total_Sales'].sum().sort_values(ascending = False).head(10)
# Out:
# product_name
# Vegetables    2397880.0
# Belt          2373559.0
# Notebook      2271101.0
# Jacket        2262042.0
# Watch         2203340.0
# Handbag       2184052.0
# Smartphone    2162824.0
# Wardrobe      2160645.0
# Sweater       2117571.0
# T-Shirt       2080951.0
# Name: Total_Sales, dtype: float64

# %%
plt.figure(figsize = (10,4))

df.groupby('product_name')['Total_Sales'].sum().sort_values(ascending = False).head(10).plot(kind = 'bar', color = 'orange')
plt.title("Top 10 Products by Total Sales")
# Out:
# Text(0.5, 1.0, 'Top 10 Products by Total Sales')

# %% [markdown]
# #  Product category

# %%
df.groupby('product_category')['quantity'].sum().sort_values(ascending = False)
# Out:
# product_category
# Clothing       1099.0
# Furniture      1014.0
# Accessories    1009.0
# Groceries      1002.0
# Books          1001.0
# Electronics     951.0
# Name: quantity, dtype: float64

# %%
plt.figure(figsize = (10,4))
s1 = df.groupby('product_category')['quantity'].sum().sort_values(ascending = False).plot(kind = 'bar')
plt.title("Product Category by Qty")
for bar in s1.containers:
    s1.bar_label(bar)

# %%
df.groupby('product_category')['Total_Sales'].sum().sort_values(ascending = False)
# Out:
# product_category
# Accessories    10365306.0
# Clothing       10195727.0
# Books           9872181.5
# Furniture       9652217.5
# Electronics     9503980.5
# Groceries       9427127.0
# Name: Total_Sales, dtype: float64

# %%
plt.figure(figsize = (10,4))
s11 = df.groupby('product_category')['Total_Sales'].sum().sort_values(ascending = False).plot(kind = 'pie', autopct = '%1.1f%%')
plt.title("Product Category by Sales")
# Out:
# Text(0.5, 1.0, 'Product Category by Sales')

# %% [markdown]
# Accessories and Clothing are the highest revenue-generating categories.
# Clothing is the most sold category in terms of quantity.

# %% [markdown]
# # Analysis on the basis of payment mode

# %%
df.groupby('payment_mode')['Total_Sales'].sum().sort_values(ascending = False)
# Out:
# payment_mode
# Credit Card    19345453.5
# Cash           10574650.0
# EMI            10066658.0
# UPI             9516887.5
# Debit Card      9512890.5
# Name: Total_Sales, dtype: float64

# %%
df.groupby('payment_mode')['Total_Sales'].sum().sort_values(ascending = False).plot(kind = 'pie', autopct = '%1.1f%%')
plt.title("Total Sales by Payment Mode")
# Out:
# Text(0.5, 1.0, 'Total Sales by Payment Mode')

# %%
df.groupby('payment_mode')['quantity'].sum().sort_values(ascending = False)
# Out:
# payment_mode
# Credit Card    1979.0
# Cash           1050.0
# EMI            1050.0
# Debit Card     1020.0
# UPI             977.0
# Name: quantity, dtype: float64

# %%
df.groupby('payment_mode')['quantity'].sum().sort_values(ascending = False).plot(kind = 'pie', autopct = '%1.1f%%')
plt.title("Total Sold Qty by Payment Mode")
# Out:
# Text(0.5, 1.0, 'Total Sold Qty by Payment Mode')

# %% [markdown]
# On analyzing the payment modes,found that customers are mostly using Credit Cards to make purchases compared to other payment methods.

# %% [markdown]
# # Analysis on the basis of status

# %%
df.groupby('status')['Total_Sales'].sum().sort_values(ascending = False)
# Out:
# status
# pending      15810149.5
# delivered    15236206.5
# returned     14226081.5
# cancelled    13744102.0
# Name: Total_Sales, dtype: float64

# %%
df.groupby('status')['Total_Sales'].sum().sort_values(ascending = False).plot(kind = 'pie', autopct = '%1.1f%%', wedgeprops = {'width' : 0.2})
# Out:
# <Axes: ylabel='Total_Sales'>

# %%
df.groupby('status')['quantity'].sum().sort_values(ascending = False).plot(kind = 'pie', autopct = '%1.1f%%', wedgeprops = {'width' : 0.2})
# Out:
# <Axes: ylabel='quantity'>

# %% [markdown]
# The business has almost equal distribution among delivered, pending, returned, and cancelled orders.
# Ideally, delivered orders should dominate
# Here, returns and cancellations are too high, which may indicate issues with product quality, customer satisfaction, or delivery process.
# Pending orders being the largest category suggests either processing delays

# %%
num = df[['customer_age', 'quantity', 'price', 'Total_Sales']]
sns.heatmap(data = num.corr(), annot = True)
# Out:
# <Axes: >

# %%
num.corr()
# Out:
#               customer_age  quantity     price  Total_Sales
# customer_age      1.000000  0.031546 -0.008692     0.005670
# quantity          0.031546  1.000000  0.626997     0.741258
# price            -0.008692  0.626997  1.000000     0.959135
# Total_Sales       0.005670  0.741258  0.959135     1.000000

# %% [markdown]
# #  Trend Analysis

# %%
df['Year'] = df['purchase_date'].dt.year
df['Month'] = df['purchase_date'].dt.to_period('M')
df['Quarter'] = df['purchase_date'].dt.to_period('Q')

# %%
plt.figure(figsize = (15,4))

sales_by_day = df.groupby('purchase_date')['Total_Sales'].sum().plot(kind = 'line')
plt.title("Day-wise Sales")
# Out:
# Text(0.5, 1.0, 'Day-wise Sales')

# %%
plt.figure(figsize = (15,4))
sales_by_month = df.groupby('Month')['Total_Sales'].sum().plot(kind = 'line')
plt.title("Month-wise Sales")
# Out:
# Text(0.5, 1.0, 'Month-wise Sales')

# %%
plt.figure(figsize = (15,4))
sales_by_quarter = df.groupby('Quarter')['Total_Sales'].sum().plot(kind = 'line')
plt.title("Quarter-wise Sales")
# Out:
# Text(0.5, 1.0, 'Quarter-wise Sales')

# %%
plt.figure(figsize = (15,4))
sales_by_year = df.groupby('Year')['Total_Sales'].sum().plot(kind = 'line')
plt.title("Year-wise Sales")
# Out:
# Text(0.5, 1.0, 'Year-wise Sales')

# %% [markdown]
# Sales are decreasing across all time periods (daily, monthly, quarterly, yearly).

# %%
df.head(3)
# Out:
#   transaction_id customer_id   customer_name  customer_age  gender product_id  \
# 0      TXN886726    CUST4481  Dhanush Bhakta          41.0  Female      P8464
# 1      TXN941069    CUST9221  Anahita Shenoy          46.0  Female      P7932
# 2      TXN132714    CUST9088    Samaira Bora          29.0  Female      P9223
#
#   product_name product_category  quantity    price payment_mode purchase_date  \
# 0         Sofa        Furniture       5.0  21410.0          UPI    2023-08-29
# 1   Sunglasses      Accessories       2.0   1156.0         Cash    2023-06-04
# 2   Sunglasses      Accessories       4.0  13828.0          UPI    2023-09-16
#
#   time_of_purchase     status  Total_Sales  Year    Month Quarter
# 0          8:16:22    pending     107050.0  2023  2023-08  2023Q3
# 1         16:24:21    pending       2312.0  2023  2023-06  2023Q2
# 2         17:36:13  cancelled      55312.0  2023  2023-09  2023Q3
